# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

train = pd.read_csv('../sale-prediction/sales_train.csv')
test = pd.read_csv('../sale-prediction/test.csv')
data = pd.read_csv('../sale-prediction/data.csv')

# %%
data
# Out:
#           date_block_num  shop_id  item_id  item_cnt_month  month  \
# 0                      0        2       19             0.0      0
# 1                      0        3       19             0.0      0
# 2                      0        4       19             0.0      0
# 3                      0        6       19             0.0      0
# 4                      0        7       19             0.0      0
# ...                  ...      ...      ...             ...    ...
# 11128045              34       49    12470             NaN     10
# 11128046              34       39    12470             NaN     10
# 11128047              34       48    12470             NaN     10
# 11128048              34       34    12470             NaN     10
# 11128049              34       36    12470             NaN     10
#
#                  city  item_category_id
# 0              Adygea                40
# 1          Balashikha                40
# 2            Volzhsky                40
# ...

# %%
group = data.loc[data.date_block_num != 34].groupby(['item_category_id','date_block_num']).agg({'item_cnt_month':['sum']})
group.columns = ['item_cat_cnt_month']
group.reset_index(inplace=True)
group
# Out:
#       item_category_id  date_block_num  item_cat_cnt_month
# 0                    0               0                 1.0
# 1                    0               1                 1.0
# 2                    0               3                 1.0
# 3                    1               0                 1.0
# 4                    1               1                 1.0
# ...                ...             ...                 ...
# 2072                83              29               258.0
# 2073                83              30               298.0
# 2074                83              31               293.0
# 2075                83              32               277.0
# 2076                83              33               348.0
#
# [2077 rows x 3 columns]

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='date_block_num', hue='item_category_id', data=data)

# %%
for i in range(0,84):
    data_i = data.loc[data.item_category_id == i]
    plt.figure(figsize=(16,8))
    sns.countplot(x='date_block_num', hue='item_category_id', data=data_i)
