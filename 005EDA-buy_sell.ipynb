# %%
# %run 004EDA-shops.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            datetime64[ns]
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 134.4 MB
# False    2935849
# Name: date, dtype: int64
# False    2935849
# Name: date_block_num, dtype: int64
# False    2935849
# Name: shop_id, dtype: int64
# False    2935849
# Name: item_id, dtype: int64
# False    2935849
# Name: item_price, dtype: int64
# False    2935849
# Name: item_cnt_day, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       214200 non-null  int64
#  1   shop_id  214200 non-null  int64
#  2   item_id  214200 non-null  int64
# dtypes: int64(3)
# memory usage: 4.9 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              214200 non-null  int64
#  1   item_cnt_month  214200 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB
# 004EDA-shops.ipynb:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   {
# 004EDA-shops.ipynb:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "cells": [
# 004EDA-shops.ipynb:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "execution_count": 3,

# %% [markdown]
# ## 買いデータと売りデータ

# %%
train_buy = train.loc[train.item_cnt_day < 0]
train_buy.head()
# Out:
#            date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 107  2013-02-01               0       59     5856     2149.00          -1.0
# 153  2013-01-30               0       59     4809      399.56          -1.0
# 544  2013-01-30               0       59     1874      199.44          -1.0
# 693  2013-09-01               0       59     4035      894.00          -1.0
# 1373 2013-10-01               0       59    12273      549.00          -1.0
#
#       year  total_price  week_day       city
# 107   2013     -2149.00         4  Yaroslavl
# 153   2013      -399.56         2  Yaroslavl
# 544   2013      -199.44         2  Yaroslavl
# 693   2013      -894.00         6  Yaroslavl
# 1373  2013      -549.00         1  Yaroslavl

# %%
train_sale = train.loc[train.item_cnt_day > 0]
train_sale.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-02-01               0       59    22154       999.0           1.0
# 1 2013-10-01               0       59    22151       399.0           1.0
# 2 2013-04-01               0       59     5603       699.0           1.0
# 3 2013-01-19               0       59     5587       199.0           2.0
# 4 2013-01-31               0       59     5613      5571.0           1.0
#
#    year  total_price  week_day       city
# 0  2013        999.0         4  Yaroslavl
# 1  2013        399.0         1  Yaroslavl
# 2  2013        699.0         0  Yaroslavl
# 3  2013        398.0         5  Yaroslavl
# 4  2013       5571.0         3  Yaroslavl

# %%
train_buy.count()
# Out:
# date              7356
# date_block_num    7356
# shop_id           7356
# item_id           7356
# item_price        7356
# item_cnt_day      7356
# year              7356
# total_price       7356
# week_day          7356
# city              7356
# dtype: int64

# %%
train_buy.item_id.value_counts()
# Out:
# 2331     56
# 3734     41
# 1915     32
# 5672     31
# 16787    27
#          ..
# 15269     1
# 6909      1
# 13052     1
# 2811      1
# 4102      1
# Name: item_id, Length: 3511, dtype: int64

# %%
items.loc[items.item_id == 2331]
# Out:
#                                         item_name  item_id  item_category_id  \
# 17824  Call of Duty: Ghosts [PS4, русская версия]     2331                20
#
#       item_category_name
# 17824         Игры - PS4

# %%
items.loc[items.item_id == 3734]
# Out:
#                                             item_name  item_id  \
# 9338  Grand Theft Auto V [Xbox 360, русские субтитры]     3734
#
#       item_category_id item_category_name
# 9338                23    Игры - XBOX 360

# %%
items.loc[items.item_id == 1915]
# Out:
#                                    item_name  item_id  item_category_id  \
# 8428  Bestseller. S.T.A.L.K.E.R. [PC, Jewel]     1915                30
#
#                  item_category_name
# 8428  Игры PC - Стандартные издания

# %%
items.loc[items.item_id == 5672]
# Out:
#                                                item_name  item_id  \
# 20427  PS4: Контроллер игровой беспроводной черный (D...     5672
#
#        item_category_id item_category_name
# 20427                 3   Аксессуары - PS4

# %%
items.loc[items.item_id == 16787]
# Out:
#                               item_name  item_id  item_category_id  \
# 8328  Одни из нас [PS3, русская версия]    16787                19
#
#      item_category_name
# 8328         Игры - PS3

# %%
train_buy.shop_id.value_counts()
# Out:
# 31    451
# 12    430
# 54    356
# 25    316
# 57    314
# 6     261
# 42    251
# 28    216
# 43    211
# 19    211
# 56    195
# 47    193
# 58    173
# 44    165
# 53    163
# 38    162
# 27    157
# 37    154
# 29    151
# 52    143
# 16    139
# 59    137
# 30    135
# 26    134
# 18    132
# 15    130
# 50    130
# 35    128
# 21    125
# 4     124
# 14    120
# 3     119
# 24    103
# 45    103
# 46    102
# 7      99
# 22     97
# 48     89
# 5      85
# 41     82
# 17     80
# 2      80
# 49     42
# 39     37
# 32     34
# 34     25
# 33     22
# 23     17
# 40     13
# 9       8
# 8       6
# 36      3
# 55      2
# 20      1
# Name: shop_id, dtype: int64

# %%
len(train_buy.shop_id.unique())
# Out:
# 54

# %%
len(shops)
# Out:
# 60

# %%
train_buy.city.value_counts()
# Out:
# Moscow         1937
# Yakutsk         487
# SPb             462
# Emergency       430
# Voronezh        366
# Khimki          356
# Ufa             306
# Samara          268
# Krasnoyarsk     212
# Kursk           211
# Chekhov         195
# Surgut          193
# Tyumen          172
# Omsk            162
# Novosibirsk     157
# N.Novgorod      153
# Kolomna         139
# Yaroslavl       137
# RostovNaDon     132
# Kaluga          130
# Volzhsky        124
# Kazan           120
# Balashikha      119
# Sergiev         102
# Tomsk            89
# Vologda          85
# Adygea           80
# Mytishchi        22
# Outbound          8
# Digital           2
# Name: city, dtype: int64

# %%
train_sale.shop_id.value_counts()
# Out:
# 31    235185
# 25    185788
# 54    143124
# 28    142018
# 57    117114
# 42    109002
# 27    105209
# 6      82402
# 58     71268
# 56     69378
# 46     66219
# 50     65043
# 19     63700
# 15     59381
# 35     58317
# 21     58008
# 7      57977
# 47     56502
# 26     53776
# 18     53095
# 24     52929
# 53     52758
# 16     52595
# 30     50725
# 29     49074
# 38     45851
# 22     45337
# 51     44433
# 52     43359
# 59     41971
# 41     41885
# 37     39484
# 44     39365
# 43     39071
# 4      38118
# 5      38094
# 14     36859
# 45     35788
# 55     34767
# 12     34264
# 2      25911
# 3      25413
# 17     22870
# 48     21523
# 10     21397
# 13     17824
# 49     15807
# 39     13403
# 0       9857
# 32      7913
# 23      6946
# 34      5727
# 1       5678
# 33      5005
# 40      4244
# 9       3743
# 8       3406
# 20      1791
# 11       499
# 36       303
# Name: shop_id, dtype: int64

# %%
train_sale.city.value_counts()
# Out:
# Moscow         994699
# Yakutsk        203917
# SPb            148073
# Voronezh       143785
# Khimki         143124
# Tyumen         125283
# Ufa             96117
# Krasnoyarsk     75965
# Samara          75153
# Chekhov         69378
# Sergiev         66219
# N.Novgorod      64044
# Kursk           63700
# RostovNaDon     59532
# Kaluga          59381
# Surgut          56502
# Kazan           54683
# Kolomna         52595
# Omsk            45851
# Yaroslavl       41971
# Novosibirsk     39787
# Volzhsky        38118
# Vologda         38094
# Digital         34767
# Emergency       34264
# Adygea          25911
# Balashikha      25413
# Zhukovsky       21896
# Tomsk           21523
# Mytishchi        5005
# Outbound         3743
# Name: city, dtype: int64

# %%
def get_buy_or_sale(x):
    if x > 0:
        return 'sale'
    else:
        return 'buy'
    
train['sale_or_buy'] = train.item_cnt_day.apply(get_buy_or_sale)
train.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-02-01               0       59    22154       999.0           1.0
# 1 2013-10-01               0       59    22151       399.0           1.0
# 2 2013-04-01               0       59     5603       699.0           1.0
# 3 2013-01-19               0       59     5587       199.0           2.0
# 4 2013-01-31               0       59     5613      5571.0           1.0
#
#    year  total_price  week_day       city sale_or_buy
# 0  2013        999.0         4  Yaroslavl        sale
# 1  2013        399.0         1  Yaroslavl        sale
# 2  2013        699.0         0  Yaroslavl        sale
# 3  2013        398.0         5  Yaroslavl        sale
# 4  2013       5571.0         3  Yaroslavl        sale
