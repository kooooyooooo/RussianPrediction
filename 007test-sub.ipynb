# %%
# %run 006data-edits.ipynb
# Out:
# 006data-edits.ipynb:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   {
# 006data-edits.ipynb:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "cell_type": "code",
# 006data-edits.ipynb:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "import pandas as pd\n",

# %%
test
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %%
sub
# Out:
#             ID  item_cnt_month
# 0            0             0.5
# 1            1             0.5
# 2            2             0.5
# 3            3             0.5
# 4            4             0.5
# ...        ...             ...
# 214195  214195             0.5
# 214196  214196             0.5
# 214197  214197             0.5
# 214198  214198             0.5
# 214199  214199             0.5
#
# [214200 rows x 2 columns]

# %%
print(len(shops))
print(len(items))
# Out:
# 60
# 22170

# %%
len(items) * len(shops)
# Out:
# 1330200

# %%
test.shop_id.unique()
# Out:
# array([ 5,  4,  6,  3,  2,  7, 10, 12, 28, 31, 26, 25, 22, 24, 21, 15, 16,
#        18, 14, 19, 42, 50, 49, 53, 52, 47, 48, 57, 58, 59, 55, 56, 36, 37,
#        35, 38, 34, 46, 41, 44, 39, 45], dtype=int64)

# %%
len(train.shop_id.unique()) - len(test.shop_id.unique())
# Out:
# 18

# %%
len(train.item_id.unique()) - len(test.item_id.unique())
# Out:
# 16707

# %%
len(test.shop_id.unique()) * len(test.item_id.unique()) == len(test) #なるほどねw
# Out:
# True

# %%
not_in_test_shop = np.setdiff1d(train.shop_id.unique(), test.shop_id.unique())
not_in_test_shop
# Out:
# array([ 0,  1,  8,  9, 11, 13, 17, 20, 23, 27, 29, 30, 32, 33, 40, 43, 51,
#        54], dtype=int64)

# %%
shops
# Out:
#                                           shop_name  shop_id  \
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# ...

# %%
not_in_test_items = np.setdiff1d(train.item_id.unique(), test.item_id.unique())
not_in_test_items
# Out:
# array([    0,     1,     2, ..., 22165, 22168, 22169], dtype=int64)

# %%
len(not_in_test_items)
# Out:
# 17070

# %%
len(items.unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-fa744dd2452c> in <module>
# ----> 1 len(items.unique())
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
len(train.item_id.unique())
# Out:
# 21807

# %%
train.shape
# Out:
# (2935849, 11)

# %%
train.item_id
# Out:
# 0          22154
# 1          22151
# 2           5603
# 3           5587
# 4           5613
#            ...
# 2935844    20231
# 2935845    20334
# 2935846    20339
# 2935847    20352
# 2935848    20602
# Name: item_id, Length: 2935849, dtype: int64

# %%
set(train.item_id) - set(test.item_id) #行けそう
# Out:
# 17070

# %%
len(test.item_id.unique())
# Out:
# 5100

# %%
def get_in_test(x):
    if x.isin()
# Out:
# 2047     42
# 19744    42
# 15406    42
# 13359    42
# 3240     42
#          ..
# 21086    42
# 21214    42
# 17244    42
# 21342    42
# 2049     42
# Name: item_id, Length: 5100, dtype: int64

# %%
train.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-02-01               0       59    22154       999.0           1.0
# 1 2013-10-01               0       59    22151       399.0           1.0
# 2 2013-04-01               0       59     5603       699.0           1.0
# 3 2013-01-19               0       59     5587       199.0           2.0
# 4 2013-01-31               0       59     5613      5571.0           1.0
#
#    year  total_price  week_day       city sale_or_buy
# 0  2013        999.0         4  Yaroslavl        sale
# 1  2013        399.0         1  Yaroslavl        sale
# 2  2013        699.0         0  Yaroslavl        sale
# 3  2013        398.0         5  Yaroslavl        sale
# 4  2013       5571.0         3  Yaroslavl        sale

# %%
train.item_id[0].isin(test.item_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-0d4af4c87fb8> in <module>
# ----> 1 train.item_id[0].isin(test.ite_id)
#
# AttributeError: 'numpy.int64' object has no attribute 'isin'
